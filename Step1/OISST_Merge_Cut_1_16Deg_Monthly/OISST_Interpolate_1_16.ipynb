# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd

# %%
def interpolate_netcdf_1_16_deg(input_file, output_file=None):
    """
    Interpolate a NetCDF file from 1-degree to 0.25-degree resolution using bilinear interpolation.
    
    Parameters:
    -----------
    input_file : str
        Path to input NetCDF file
    output_file : str, optional
        Path to save the interpolated NetCDF file. If None, returns the dataset without saving.
    
    Returns:
    --------
    xarray.Dataset
        Interpolated dataset at 0.0625-degree resolution
    """
    # Read the input NetCDF file
    ds_raw = xr.open_dataset(input_file)
    ds = ds_raw.sst
    # Create new coordinate arrays for 0.25-degree resolution
    new_lat = np.arange(ds.lat.min(), ds.lat.max() + 0.0625, 0.0625)
    new_lon = np.arange(ds.lon.min(), ds.lon.max() + 0.0625, 0.0625)
    
    # Perform bilinear interpolation
    ds_interpolated = ds.interp(
        lat=new_lat,
        lon=new_lon,
        method='linear'  # This performs bilinear interpolation for 2D data
    )
    
    # Save to file if output_file is specified
    if output_file:
        ds_interpolated.to_netcdf(output_file)
        print(f"Interpolated data saved to: {output_file}")
    
    return ds_interpolated

# %%
nc_file_path = r"C:\Users\lv299\OneDrive\STF_Paper\Subtropical-Front-Modeling-Code\Step1\OISST_Merge_Cut_1_4Deg_Monthly\OISST_1_4Deg_monthly.nc"

oisst_1_16_deg = interpolate_netcdf_1_16_deg(nc_file_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18244\4287145106.py in <module>
#       1 nc_file_path = r"C:\Users\lv299\OneDrive\STF_Paper\Subtropical-Front-Modeling-Code\Step1\OISST_Merge_Cut_1_4Deg_Monthly\OISST_1_4Deg_monthly.nc"
#       2
# ----> 3 oisst_1_16_deg = interpolate_netcdf_1_16_deg(nc_file_path)
#
# NameError: name 'interpolate_netcdf_1_16_deg' is not defined

# %%
time_array = pd.date_range(start='2004-01-01', end='2023-12-15', freq='MS') + pd.Timedelta(days=14)
oisst_1_16_deg['time'] = time_array

# %%
oisst_1_16_deg.to_netcdf('oisst_1_16_deg.nc')

# %%
test = xr.open_dataset('oisst_1_16_deg.nc')
test
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 240, lat: 325, lon: 5757)
# Coordinates:
#   * time     (time) datetime64[ns] 2004-01-15 2004-02-15 ... 2023-12-15
#   * lat      (lat) float64 -50.12 -50.06 -50.0 -49.94 ... -30.0 -29.94 -29.88
#   * lon      (lon) float64 0.125 0.1875 0.25 0.3125 ... 359.7 359.8 359.8 359.9
# Data variables:
#     sst      (time, lat, lon) float64 ...
