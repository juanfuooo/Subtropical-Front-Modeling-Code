# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd

# %%
oisst = xr.open_dataset(r'C:\Users\lv299\OneDrive\STF_Paper\Subtropical-Front-Modeling-Code\Step1\OISST_Merge_Cut_1_4Deg_Daily\Cut_Merge\OISST_1_4Deg_daily.nc')

oisst
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 7305, lat: 82, lon: 1440)
# Coordinates:
#   * lat      (lat) float64 -50.12 -49.88 -49.62 -49.38 ... -30.38 -30.12 -29.88
#   * lon      (lon) float64 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) float64 1.0 2.0 3.0 4.0 ... 7.303e+03 7.304e+03 7.305e+03
# Data variables:
#     sst      (time, lat, lon) float64 ...

# %%
oisst['time'] = pd.date_range('2004-01-01', periods=oisst.sizes['time'], freq='D')
oisst
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 7305, lat: 82, lon: 1440)
# Coordinates:
#   * lat      (lat) float64 -50.12 -49.88 -49.62 -49.38 ... -30.38 -30.12 -29.88
#   * lon      (lon) float64 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2023-12-31
# Data variables:
#     sst      (time, lat, lon) float64 ...

# %%
oisst.to_netcdf(r'C:\Users\lv299\OneDrive\STF_Paper\Subtropical-Front-Modeling-Code\Step1\OISST_1_4Deg_daily.nc')
