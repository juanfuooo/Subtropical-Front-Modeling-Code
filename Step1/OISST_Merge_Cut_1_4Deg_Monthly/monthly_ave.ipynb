# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd

# %%
oisst = xr.open_dataset(r'C:\Users\lv299\OneDrive\STF_Paper\Subtropical-Front-Modeling-Code\Step1\OISST_1_4Deg_daily.nc')
oisst
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 7305, lat: 82, lon: 1440)
# Coordinates:
#   * lat      (lat) float64 -50.12 -49.88 -49.62 -49.38 ... -30.38 -30.12 -29.88
#   * lon      (lon) float64 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * time     (time) datetime64[ns] 2004-01-01 2004-01-02 ... 2023-12-31
# Data variables:
#     sst      (time, lat, lon) float64 ...

# %%
oisst_monthly = oisst.resample(time='1MS').mean()
oisst_monthly
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 240, lat: 82, lon: 1440)
# Coordinates:
#   * time     (time) datetime64[ns] 2004-01-01 2004-02-01 ... 2023-12-01
#   * lat      (lat) float64 -50.12 -49.88 -49.62 -49.38 ... -30.38 -30.12 -29.88
#   * lon      (lon) float64 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
# Data variables:
#     sst      (time, lat, lon) float64 3.261 3.377 3.497 ... 21.88 21.88 21.81

# %%
oisst_monthly.to_netcdf(r'C:\Users\lv299\OneDrive\STF_Paper\Subtropical-Front-Modeling-Code\Step1\OISST_Merge_Cut_1_4Deg_Monthly\OISST_1_4Deg_monthly.nc')
